# %%
# !pwd
# !ls -l

import json

with open("/home/egoodman/full-youtube-dataset/datasets/all_video_metadata.json") as json_file:
    data = json.load(json_file)
    

for i, ytid in enumerate(data.keys()):
    
    print("\n\n\nDownloading video number", i)
    
    base = "https://www.youtube.com/watch?v="
    complete = base + ytid
    
    print(complete)
    
    # !youtube-dl -f 133 --cookies=~/bin/cookies.txt $complete
    
    
    if i == 400:
        break
# Out:
# /home/egoodman/multitaskmodel/data/surgical_signatures/pseudo-videos
# total 9728
# -rw-rw-r-- 1 egoodman egoodman 9955491 Jun 26 23:43 '#appendectomy     #openappendectomy Open Appendectomy _ Appendectomy _ open appendectomy steps-AazlRmkIur0.mp4'
# -rw-rw-r-- 1 egoodman egoodman    2061 Jun 28 18:45  download_vids_for_pseudoannotation.ipynb
#
#
#
# ...
# https://www.youtube.com/watch?v=AazlRmkIur0
# [youtube] AazlRmkIur0: Downloading webpage
# [youtube] AazlRmkIur0: Downloading MPD manifest
# [download] #appendectomy     #openappendectomy Open Appendectomy _ Appendectomy _ open appendectomy steps-AazlRmkIur0.mp4 has already been downloaded
# [download] 100% of 9.49MiB
#
#
#
# ...
# https://www.youtube.com/watch?v=eW7HJkBFWRM
# [youtube] eW7HJkBFWRM: Downloading webpage
# [youtube] eW7HJkBFWRM: Downloading MPD manifest
# [dashsegments] Total fragments: 14
# [download] Destination: #AXILLARY FAT PAD# liposuction-eW7HJkBFWRM.mp4
# [download] 100% of 393.78KiB in 00:04.32MiB/s ETA 00:0006
#
#
#
# ...
