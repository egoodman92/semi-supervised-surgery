# %%
'''
Rohan's version 
train.ipynb 
9/21/2020 

'''
import argparse
import collections
from pathlib import Path
import csv
import os 

import numpy as np 

import torch
import torch.optim as optim
from torchvision import transforms, utils as vision_utils 
#from torch.utils.tensorboard import SummaryWriter

from retinanet import model
from retinanet.dataloader import CocoDataset, CSVDataset, collater, Resizer, AspectRatioBasedSampler, Augmenter, \
    Normalizer, BalancedSampler
from torch.utils.data import DataLoader

from retinanet.sampler import SamplerFactory, aggregate_indices_per_class 


from retinanet import coco_eval
from retinanet import csv_eval

assert torch.__version__.split('.')[0] == '1'
# Out:
# /home/ubuntu/anaconda3/envs/tools/lib/python3.7/site-packages/imgaug/imgaug.py:184: DeprecationWarning: Function `SimplexNoiseAlpha()` is deprecated. Use `BlendAlphaSimplexNoise` instead. SimplexNoiseAlpha is deprecated. Use BlendAlphaSimplexNoise instead. The order of parameters is the same. Parameter 'first' was renamed to 'foreground'. Parameter 'second' was renamed to 'background'.
#   warn_deprecated(msg, stacklevel=3)
# /home/ubuntu/anaconda3/envs/tools/lib/python3.7/site-packages/imgaug/imgaug.py:184: DeprecationWarning: Function `FrequencyNoiseAlpha()` is deprecated. Use `BlendAlphaFrequencyNoise` instead. FrequencyNoiseAlpha is deprecated. Use BlendAlphaFrequencyNoise instead. The order of parameters is the same. Parameter 'first' was renamed to 'foreground'. Parameter 'second' was renamed to 'background'.
#   warn_deprecated(msg, stacklevel=3)

# %%
MODELS_DIR = '/home/ubuntu/surgery-tool-detection/models/'
LOGS_DIR = '/home/ubuntu/surgery-tool-detection/logs/'

##MODELS_DIR = str(Path(__file__).resolve().parents[2]) + '/models/'
##LOGS_DIR = str(Path(__file__).resolve().parents[2]) + '/logs/'
# pretrained_model = MODELS_DIR + 'coco_resnet_50_map_0_335_state_dict.pt'

print('CUDA available: {}'.format(torch.cuda.is_available()))

print(MODELS_DIR) 

print(LOGS_DIR)
# Out:
# CUDA available: True
# /home/ubuntu/surgery-tool-detection/models/
# /home/ubuntu/surgery-tool-detection/logs/

# %% [markdown]
# ## Set up model configs

# %%
### Set up model configs ### 

parser = argparse.ArgumentParser(description='Simple training script for training a RetinaNet network.')

parser.add_argument('--dataset', help='Dataset type, must be one of csv or coco.')
parser.add_argument('--coco_path', help='Path to COCO directory')
parser.add_argument('--csv_train', help='Path to file containing training annotations (see readme)')
parser.add_argument('--csv_classes', help='Path to file containing class list (see readme)')
parser.add_argument('--csv_val', help='Path to file containing validation annotations (optional, see readme)')

parser.add_argument('--depth', help='Resnet depth, must be one of 18, 34, 50, 101, 152', type=int, default=50)
parser.add_argument('--epochs', help='Number of epochs', type=int, default=100)
parser.add_argument('--model_name', help='Name to store the trianed model under.')
parser.add_argument('--log_output', help='Save output to csv file', action='store_true')
parser.add_argument('--batch_size', type=int)
parser.add_argument('--learning_rate', type=float)
parser.add_argument('--threshold', help='iou threshold to count as detection')
parser.add_argument('--sampler', help='Type of sampler to use, default aspect ratio sampler.')
parser.add_argument('--augment', action='store_true')
parser.add_argument('--pretrained', help='Path to pretrained model')
parser.add_argument('--blacken', action='store_true')

#parser = parser.parse_args(args)


##### PRIMARY MODEL CONFIGS TO SET ### 

parser.model_name = '9.28_Model3' 

parser.augment = 0.9 #1.0 #0.7 #False 
parser.pipeline = 'my_pipeline_v2' #"kitchen_sink" #"my_pipeline_v3" #"rotate" #"my_pipeline_v1" #False 

#parser.sampler = None 
#parser.sampler = "old balanced (no alpha)" 
parser.sampler = 'new balanced' 
parser.alpha = 0.9   

parser.depth = 50 
parser.epochs = 60  
parser.num_workers = 3

##### END PRIMARY CONFIGS ######## 



parser.log_output = True 
LOG_DIR = LOGS_DIR + parser.model_name + '/'
os.makedirs(LOG_DIR, exist_ok=True) 

parser.dataset = 'csv' 
parser.csv_train = '/home/ubuntu/surgery-tool-detection/src/data/train_data.csv' #'../data/train_data.csv'
parser.csv_val = '/home/ubuntu/surgery-tool-detection/src/data/val_data.csv' #../val_data.csv 
parser.csv_classes = '/home/ubuntu/surgery-tool-detection/src/data/class_names_prune.csv' #../data/class_names.csv 


parser.blacken = False 
parser.learning_rate = None 

parser.batch_size = None ## Set and log config? 
parser.threshold = None ## Set and log config? 



configs = ['model_name', 'augment', 'pipeline', 'sampler', 'alpha', 'depth', 'epochs', 'num_workers'] #, log_output, dataset, csv_train] 

filename = '{}_configs.txt'.format(LOG_DIR + parser.model_name) 
config_log = open(filename, 'w') 

for config in configs: 
    value = getattr(parser, config) 
    output_line = '{}: {}\n'.format(config, value) 
    print(output_line) 
    config_log.write(output_line) 

config_log.close()
# Out:
# model_name: 9.28_Model3
#
# augment: 0.9
#
# pipeline: my_pipeline_v2
#
# sampler: new balanced
#
# alpha: 0.9
#
# depth: 50
#
# epochs: 60
#
# num_workers: 3

# %% [markdown]
# ## Set up dataloaders, model, logging

# %%
model_name = 'model'
if parser.model_name is not None:
    model_name = parser.model_name

learning_rate = 1e-5
if parser.learning_rate is not None:
    learning_rate = float(parser.learning_rate)

batch_size = 2
if parser.batch_size is not None:
    batch_size = int(parser.batch_size)

threshold = 0.5
if parser.threshold is not None:
    threshold = float(parser.threshold)

# %%
# Create the dataloaders     

if parser.dataset == 'coco':

    if parser.coco_path is None:
        raise ValueError('Must provide --coco_path when training on COCO,')

    dataset_train = CocoDataset(parser.coco_path, set_name='train2017',
                                transform=transforms.Compose([Normalizer(), Augmenter(), Resizer()]))
    dataset_val = CocoDataset(parser.coco_path, set_name='val2017',
                              transform=transforms.Compose([Normalizer(), Resizer()]))

elif parser.dataset == 'csv':

    if parser.csv_train is None:
        raise ValueError('Must provide --csv_train when training on COCO,')

    if parser.csv_classes is None:
        raise ValueError('Must provide --csv_classes when training on COCO,')

    dataset_train = CSVDataset(train_file=parser.csv_train, class_list=parser.csv_classes,
                               transform=transforms.Compose([Normalizer(), Augmenter(), Resizer()]), 
                               augment=parser.augment, pipeline=parser.pipeline, blacken=parser.blacken)
    train_acc_set = CSVDataset(train_file=parser.csv_train, class_list=parser.csv_classes,
                               transform=transforms.Compose([Normalizer(), Resizer()]), blacken=parser.blacken)

    if parser.csv_val is None:
        dataset_val = None
        print('No validation annotations provided.')
    else:
        dataset_val = CSVDataset(train_file=parser.csv_val, class_list=parser.csv_classes,
                                 transform=transforms.Compose([Normalizer(), Resizer()]))

else:
    raise ValueError('Dataset type not understood (must be csv or coco), exiting.')
    


sampler = AspectRatioBasedSampler(dataset_train, batch_size=batch_size, drop_last=False)
if parser.sampler is not None and parser.sampler == 'old balanced (no alpha)':
    sampler = BalancedSampler(dataset_train, batch_size=batch_size, drop_last=False) 
if parser.sampler is not None and parser.sampler == 'new balanced': 
    class_indices_dict = aggregate_indices_per_class(dataset_train) 
    class_indices = list(class_indices_dict.values()) 
    # print(len(class_indices)) 
    # for label in class_indices: print(len(label))
    #batch_sz = 2 
    # print("Hello") 
    # print(len(dataset_train)//batch_sz) 
    sampler = SamplerFactory().get(
        class_idxs=class_indices,
        batch_size=batch_size,
        n_batches=len(dataset_train)//batch_size,
        alpha=parser.alpha,
        kind='random'
    ) 
    
    
dataloader_train = DataLoader(dataset_train, num_workers=parser.num_workers, collate_fn=collater, batch_sampler=sampler) 


if dataset_val is not None:
    sampler_val = AspectRatioBasedSampler(dataset_val, batch_size=1, drop_last=False)
    dataloader_val = DataLoader(dataset_val, num_workers=parser.num_workers, collate_fn=collater, batch_sampler=sampler_val)
# Out:
# Using new Balanced Sampler

# %%
# Observe dataset 

# Make sure augmentations are being preserved in the dataset! 
# And this iterates in order so can see how augmentation changes as you run the pipeline over and over 


import matplotlib.pyplot as plt 
import cv2 
from retinanet.dataloader import CocoDataset, CSVDataset, collater, Resizer, AspectRatioBasedSampler, Augmenter, \
    UnNormalizer, Normalizer
unnormalize = UnNormalizer()

# print(len(dataset_train.image_data)) 
# print(len(dataset_val.image_data)) 

print(len(dataset_train)) 

for idx, sample in enumerate(dataset_train): 
    
    print(idx) 
    print(sample['img'].shape)  
    image = sample['img'] 
    plt.imshow(image) 
    plt.show() 
    
    if idx == 0: break 
        
        
print(len(dataset_val)) 

for idx, sample in enumerate(dataset_val): 
    
    print(idx) 
    print(sample['img'].shape)  
    image = sample['img'] 
    plt.imshow(image) 
    plt.show() 
    
    if idx == 0: break
# Out:
# 2450
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0
# torch.Size([608, 1056, 3])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 430
# 0
# torch.Size([640, 832, 3])

# %%
### Observe dataloader (Playing around cell)

# Check dataloader 
# Check dataloader augmentations: pipeline + frequency 
# Check dataloader batch logging properties like filename, vidID, tools present 
# Check dataloader sampling logic (over/undersampling) 

import matplotlib.pyplot as plt 
import cv2 
from retinanet.dataloader import CocoDataset, CSVDataset, collater, Resizer, AspectRatioBasedSampler, Augmenter, \
    UnNormalizer, Normalizer

unnormalize = UnNormalizer()

def draw_caption(image, box, caption): 
    b = np.array(box).astype(int)
    cv2.putText(image, caption, (b[0], b[1] + 20), cv2.FONT_HERSHEY_PLAIN, 2, (255, 255, 255), 2)
        

from collections import defaultdict 
from retinanet.train_utils import BatchLogger 


batchLogger = BatchLogger()      

batchLogger.index = {} 
class_indices_dict = aggregate_indices_per_class(dataset_train) 
# for class_, idxs in class_indices_dict.items(): 
#     idxdict = dict.fromkeys(idxs, [0, 0])  
#     batchLogger.index[class_] = idxdict 

for class_, idxs in class_indices_dict.items(): 
    idxdict = {idx : [0, 0] for idx in idxs} 
    batchLogger.index[class_] = idxdict
    
#print(batchLogger.index) 

# print(len(dataloader_train)) 
# print(len(dataloader_val)) 


for idx, data in enumerate(dataloader_train): 
    #if idx > 10: break 
    if idx > 2: break
    print(idx) 
#     print(data) 
#     print(len(data['img'])) 
#     print(len(data['annot'])) 
#     print(data['img'][0]) 
#     plt.imshow(data['img'][0]) 
#     plt.show() 
#     print(data) 
#     print(data['img'].shape) 
#     print(data['annot']) 
#     print(data['filename']) 


    for i in range(len(data['img'])): 
        img = np.array(255 * unnormalize(data['img'][i, :, :, :])).copy() # 1. Unnormalize 
        img[img < 0] = 0
        img[img > 255] = 255 
        img = np.transpose(img, (1, 2, 0))  # 2. Tranpose to correct channel in correct spot 
        img = cv2.cvtColor(img.astype(np.uint8), cv2.COLOR_BGR2RGB) # 3. Convert to correct color space 
        
        filename = data['filename'][i] 
        filename = filename.rsplit('/',1)[1] 
        videoID = '-'.join(filename.split('-')[:-1]) 
        print(filename) 
        print(videoID) 
        augmented = data['augmented'][i] 
        print(augmented) 
        
        index = data['index'][i] 
        print("index: ", index) 
        for class_, idxsdict in batchLogger.index.items(): 
            if index in idxsdict.keys(): 
                #print(batchLogger.index[class_]) 
                batchLogger.index[class_][index][augmented] += 1 
                #print(batchLogger.index[class_]) 
                break 
            
        
        batchLogger.filename[filename] += 1 
        batchLogger.videoID[videoID] += 1 
        
        tools_present = False 
        bovi = False 
        need = False 
        forc = False 
        scal = False 
        
        annots = np.array(data['annot'][i]) 
        for annot in annots:
            if annot[4] == -1: 
                continue 
            label_name = dataset_val.labels[annot[4]]
            
            print(label_name) 
            batchLogger.tool[label_name][augmented] += 1
            tools_present = True 
            if label_name == 'bovie': bovi = True 
            if label_name == 'needledriver': need = True 
            if label_name == 'forceps': forc = True 
            if label_name == 'scalpel': scal = True 
        
            
            x1 = int(annot[0])
            y1 = int(annot[1])
            x2 = int(annot[2])
            y2 = int(annot[3])
            draw_caption(img, (x1, y1, x2, y2), label_name)
            cv2.rectangle(img, (x1, y1), (x2, y2), color=(0, 0, 255), thickness=2)  
        
        plt.imshow(img[:, :, ::-1]) 
        plt.show() 
        #cv2.imwrite("inputvis/trainground_{}.png".format(idx), img) 
        
        if tools_present: 
            batchLogger.background['tools_present'] += 1 
        else: 
            batchLogger.background['tools_absent'] += 1
        if bovi : batchLogger.tool_frame['bovie'][augmented] += 1
        if need : batchLogger.tool_frame['needledriver'][augmented] += 1
        if forc : batchLogger.tool_frame['forceps'][augmented] += 1
        if scal : batchLogger.tool_frame['scalpel'][augmented] += 1
    

batchLogger.dictify()
# Out:
# Using new Balanced Sampler
# 0
# BdLSt0VARKU-000000557.jpg
# BdLSt0VARKU
# 1
# index:  776
# needledriver
# bM0gMFbQJ-E-000002944.jpg
# bM0gMFbQJ-E
# 1
# index:  2262
# forceps
# 1
# Nqyq0uaEBOg-000000530.jpg
# Nqyq0uaEBOg
# 1
# index:  130
# bovie
# forceps
# WJ2jS88EUmo-000006148.jpg
# WJ2jS88EUmo
# 1
# index:  318
# needledriver
# 2
# sWxGr_rj7rM-000002974.jpg
# sWxGr_rj7rM
# 1
# index:  562
# bovie
# JuUFXltasaU-000002164.jpg
# JuUFXltasaU
# 1
# index:  1982

# %%
# Create the model

if parser.depth == 18:
    retinanet = model.resnet18(num_classes=dataset_train.num_classes(), pretrained=True)
elif parser.depth == 34:
    retinanet = model.resnet34(num_classes=dataset_train.num_classes(), pretrained=True)
elif parser.depth == 50:
    retinanet = model.resnet50(num_classes=dataset_train.num_classes(), pretrained=True)
elif parser.depth == 101:
    retinanet = model.resnet101(num_classes=dataset_train.num_classes(), pretrained=True)
elif parser.depth == 152:
    retinanet = model.resnet152(num_classes=dataset_train.num_classes(), pretrained=True)
else:
    raise ValueError('Unsupported model depth, must be one of 18, 34, 50, 101, 152')

# %%
# Create the loggers 

#tb = SummaryWriter('runs/{}'.format(model_name)) 

if parser.log_output:
    print('Logging training loss under {}_loss.csv'.format(LOG_DIR + model_name))
    loss_f = open('{}_loss.csv'.format(LOG_DIR + model_name), 'w')
    loss_logger = csv.writer(loss_f, delimiter=',')
    loss_logger.writerow(['Epoch', 'Iteration', 'Classification Loss', 'Regression Loss', 'Running Loss'])

    print('Logging training accuracy under {}_train.csv'.format(LOG_DIR + model_name))
    train_f = open('{}_train.csv'.format(LOG_DIR + model_name), 'w')
    train_logger = csv.writer(train_f, delimiter=',')
    train_logger.writerow(['Epoch'] + [dataset_train.label_to_name(label) for label in (0, 2, 3)] #range(dataset_train.num_classes())]
                         + ['Overall']) 
    
    
    print('Logging batch construction per epoch under {}_batches.csv'.format(LOG_DIR + model_name)) 
    batch_f = open('{}_batches.csv'.format(LOG_DIR + model_name), 'w') 
    batch_logger = csv.writer(batch_f, delimiter=',') 
    batch_logger.writerow(['Epoch'] 
                      + ['Total {}'.format(dataset_train.label_to_name(label)) for label in (0, 2, 3)] #range(dataset_train.num_classes())]
                      + ['Normal {}'.format(dataset_train.label_to_name(label)) for label in (0, 2, 3)] #range(dataset_train.num_classes())]
                      + ['Augmented {}'.format(dataset_train.label_to_name(label)) for label in (0, 2, 3)] #range(dataset_train.num_classes())]
                     ) 

    
    if parser.csv_val is not None:
        print('Logging validation output under {}_validation.csv'.format(LOG_DIR + model_name))
        validation_f = open('{}_validation.csv'.format(LOG_DIR + model_name), 'w')
        val_logger = csv.writer(validation_f, delimiter=',')
        val_logger.writerow(
            ['Epoch'] + [dataset_val.label_to_name(label) for label in (0, 2, 3)] #range(dataset_val.num_classes())] 
                         + ['Overall'])
# Out:
# Logging training loss under /home/ubuntu/surgery-tool-detection/logs/9.28_Model3/9.28_Model3_loss.csv
# Logging training accuracy under /home/ubuntu/surgery-tool-detection/logs/9.28_Model3/9.28_Model3_train.csv
# Logging batch construction per epoch under /home/ubuntu/surgery-tool-detection/logs/9.28_Model3/9.28_Model3_batches.csv
# Logging validation output under /home/ubuntu/surgery-tool-detection/logs/9.28_Model3/9.28_Model3_validation.csv

# %% [markdown]
# ## More model setup

# %%
use_gpu = True

if use_gpu:
    if torch.cuda.is_available():
        retinanet = retinanet.cuda()

if torch.cuda.is_available():
    retinanet = torch.nn.DataParallel(retinanet).cuda()
else:
    retinanet = torch.nn.DataParallel(retinanet)

print(retinanet) 
# Ensure that the model is wrapped in only a single nn.DataParallel wrapper! 
# Once this cell has been run once, don't run again!  Restart kernel if you do.
# Out:
# DataParallel(
#   (module): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (fpn): PyramidFeatures(
#       (P5_1): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       (P5_upsampled): Upsample(scale_factor=2.0, mode=nearest)
#       (P5_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (P4_1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       (P4_upsampled): Upsample(scale_factor=2.0, mode=nearest)
#       (P4_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (P3_1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#       (P3_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (P6): Conv2d(2048, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (P7_1): ReLU()
#       (P7_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (regressionModel): RegressionModel(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (act1): ReLU()
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (act2): ReLU()
#       (conv3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (act3): ReLU()
#       (conv4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (act4): ReLU()
#       (output): Conv2d(256, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (classificationModel): ClassificationModel(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (act1): ReLU()
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (act2): ReLU()
#       (conv3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (act3): ReLU()
#       (conv4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (act4): ReLU()
#       (output): Conv2d(256, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (output_act): Sigmoid()
#     )
#     (anchors): Anchors()
#     (regressBoxes): BBoxTransform()
#     (clipBoxes): ClipBoxes()
#     (focalLoss): FocalLoss()
#   )
# )

# %%
retinanet.training = True

optimizer = optim.Adam(retinanet.parameters(), lr=learning_rate)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3, verbose=True)

loss_hist = collections.deque(maxlen=500)

retinanet.train()

print('Num training images: {}'.format(len(dataset_train)))

print('Num val images: {}'.format(len(dataset_val)))
# Out:
# Num training images: 2450
# Num val images: 430

# %% [markdown]
# ## Training loop

# %%
import time

import matplotlib.pyplot as plt 
from collections import defaultdict 
from retinanet.train_utils import BatchLogger 


batchLogger = BatchLogger()                   
master_batch_logger = {} 

batchLogger.index = {} 
class_indices_dict = aggregate_indices_per_class(dataset_train) 
for class_, idxs in class_indices_dict.items(): 
    idxdict = {idx : [0, 0] for idx in idxs} 
    batchLogger.index[class_] = idxdict


t0 = time.time() 


for epoch_num in range(parser.epochs):

    retinanet.train()
    retinanet.module.freeze_bn()
    
    # Timing 
    t1 = time.time()
    tot_secs = t1-t0 
    secs = tot_secs % (24 * 3600) 
    hrs = secs // 3600
    secs %= 3600
    mins = secs // 60
    secs %= 60
    print("%d:%02d:%02d" % (hrs, mins, secs)) 
    print("to train {} epochs".format(epoch_num))         

    epoch_loss = []

    for iter_num, data in enumerate(dataloader_train):         

        try:
            
            # Batch logging! 
            
            for i in range(len(data['img'])):     
                filename = data['filename'][i].rsplit('/',1)[1] 
                videoID = '-'.join(filename.split('-')[:-1]) 
                index = data['index'][i] 
                augmented = data['augmented'][i]  

                batchLogger.filename[filename] += 1 
                batchLogger.videoID[videoID] += 1 
                for class_, idxsdict in batchLogger.index.items(): 
                    if index in idxsdict.keys(): 
                        batchLogger.index[class_][index][augmented] += 1 
                        break 

                tools_present = False 
                bovi = False 
                need = False 
                forc = False 
                scal = False 

                annots = np.array(data['annot'][i]) 
                for annot in annots:
                    if annot[4] == -1: 
                        continue 
                    label_name = dataset_val.labels[annot[4]]
                    batchLogger.tool[label_name][augmented] += 1
                    tools_present = True 
                    if label_name == 'bovie': bovi = True 
                    if label_name == 'needledriver': need = True 
                    if label_name == 'forceps': forc = True 
                    if label_name == 'scalpel': scal = True 

                if tools_present: 
                    batchLogger.background['tools_present'] += 1 
                else: 
                    batchLogger.background['tools_absent'] += 1
                if bovi : batchLogger.tool_frame['bovie'][augmented] += 1
                if need : batchLogger.tool_frame['needledriver'][augmented] += 1
                if forc : batchLogger.tool_frame['forceps'][augmented] += 1
                if scal : batchLogger.tool_frame['scalpel'][augmented] += 1
                if not tools_present : 
                    batchLogger.tool_frame['background'][augmented] += 1
                    batchLogger.tool['background'][augmented] += 1
            
            
            # Training 
            
            optimizer.zero_grad()

            if torch.cuda.is_available():
                classification_loss, regression_loss = retinanet([data['img'].cuda().float(), data['annot']])
            else:
                classification_loss, regression_loss = retinanet([data['img'].float(), data['annot']])

            classification_loss = classification_loss.mean()
            regression_loss = regression_loss.mean()

            loss = classification_loss + regression_loss

            if bool(loss == 0):
                continue

            loss.backward()

            torch.nn.utils.clip_grad_norm_(retinanet.parameters(), 0.1)

            optimizer.step()

            loss_hist.append(float(loss))

            epoch_loss.append(float(loss))
            
            if iter_num % 20 == 0: 
                print('Epoch: {} | Iteration: {} | Classification loss: {:1.5f} | Regression loss: {:1.5f} | Running loss: {:1.5f}'.format(
                        epoch_num, iter_num, float(classification_loss), float(regression_loss), np.mean(loss_hist)))

            if parser.log_output:
                loss_logger.writerow(['{}'.format(epoch_num), '{}'.format(iter_num), '{:1.5f}'.format(float(classification_loss)),
                                       '{:1.5f}'.format(float(regression_loss)), '{:1.5f}'.format(np.mean(loss_hist))])
                loss_f.flush()
                validation_f.flush()
                train_f.flush()
                batch_f.flush() 

            del classification_loss
            del regression_loss
        except Exception as e:
            print("Exception triggered") 
            print(e)
            continue

    if parser.dataset == 'coco':

        print('Evaluating dataset')

        coco_eval.evaluate_coco(dataset_val, retinanet)

    elif parser.dataset == 'csv' and parser.csv_val is not None:
        
        if epoch_num % 10 == 1:
            print('Evaluating dataset on training')
            train_mAP, train_pr = csv_eval.evaluate(train_acc_set, retinanet, iou_threshold=threshold)
            #tb.add_scalars('Training mAP', {train_acc_set.label_to_name(label): train_mAP[label][0] for label in
            #                                range(train_acc_set.num_classes())}, epoch_num)
            overall_train_mAP = np.mean(np.array([train_mAP[label][0] for label in (0, 2, 3)])) #range(dataset_train.num_classes())])) 
            print("Overall: {}".format(overall_train_mAP)) 

        print('Evaluating dataset on validation')
        mAP, pr_curve = csv_eval.evaluate(dataset_val, retinanet, iou_threshold=threshold)
        #tb.add_scalars('Validation mAP', {dataset_val.label_to_name(label): mAP[label][0] for label in
        #                                range(dataset_val.num_classes())}, epoch_num)
        overall_mAP = np.mean(np.array([mAP[label][0] for label in (0, 2, 3)])) #range(dataset_val.num_classes())])) 
        print("Overall: {}".format(overall_mAP)) 

        if parser.log_output:
            val_logger.writerow([str(epoch_num)] + [mAP[label][0] for label in (0, 2, 3)]) #range(dataset_val.num_classes())] + [overall_mAP])
            if epoch_num % 10 == 1:
                train_logger.writerow([str(epoch_num)] + [train_mAP[label][0] for label in (0, 2, 3)]) #range(dataset_train.num_classes())] + [overall_train_mAP])

                
        # Batch logging!  (Per epoch)  
        tooldict, toolframedict = batchLogger.tool, batchLogger.tool_frame #batchLogger 
        master_batch_logger[epoch_num] = tooldict, toolframedict 
        batch_logger.writerow([str(epoch_num)] 
                          + [np.sum(batchLogger.tool[dataset_train.label_to_name(label)]) for label in (0, 2, 3)] #range(dataset_train.num_classes())]
                          + [batchLogger.tool[dataset_train.label_to_name(label)][0] for label in (0, 2, 3)] #range(dataset_train.num_classes())]
                          + [batchLogger.tool[dataset_train.label_to_name(label)][1] for label in (0, 2, 3)] #range(dataset_train.num_classes())]
                         )
        print(batchLogger.tool) #
        
        # Save final batch logger state to .txt file.  Overwrite on every epoch. 
        attributes = ['filename', 'videoID', 'index', 'tool', 'tool_frame', 'background'] 
        filename = '{}_finalBatchLogger.txt'.format(LOG_DIR + parser.model_name) 
        final_batch_log = open(filename, 'w') 
        batchLogger.dictify() 
    
        final_batch_log.write("Epoch: " + str(epoch_num) + '\n') 
        for a in attributes: 
            out_dict = getattr(batchLogger, a) 
            if a == 'index': 
                for k, v in out_dict.items(): 
                    final_batch_log.write(str(k)) 
                    final_batch_log.write('\n') 
                    final_batch_log.write(str(v))
                    final_batch_log.write('\n') 
            else: 
                final_batch_log.write(str(out_dict)) 
                final_batch_log.write('\n') 
        final_batch_log.close() 
        
        batchLogger.undictify() 
        
                
    scheduler.step(np.mean(epoch_loss))

    torch.save(retinanet.module, '{}_incomplete.pt'.format(LOG_DIR + model_name))
    
    
loss_f.close()
train_f.close()
validation_f.close()
# batch_f.close() 
retinanet.eval()

torch.save(retinanet, '{}_final.pt'.format(LOG_DIR + model_name))
# Out:
# Using new Balanced Sampler
# 0:00:00
# to train 0 epochs
# /home/ubuntu/surgery-tool-detection/src/pytorch-retinanet/retinanet/model.py:52: UserWarning: Mixed memory format inputs detected while calling the operator. The operator will output contiguous tensor even if some of the inputs are in channels_last format. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629403081/work/aten/src/ATen/native/TensorIterator.cpp:918.)
#   P4_x = P5_upsampled_x + P4_x
# /home/ubuntu/surgery-tool-detection/src/pytorch-retinanet/retinanet/model.py:57: UserWarning: Mixed memory format inputs detected while calling the operator. The operator will output channels_last tensor even if some of the inputs are not in channels_last format. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629403081/work/aten/src/ATen/native/TensorIterator.cpp:924.)
#   P3_x = P3_x + P4_upsampled_x
# Epoch: 0 | Iteration: 20 | Classification loss: 1.13865 | Regression loss: 1.01398 | Running loss: 1.57835
# Epoch: 0 | Iteration: 40 | Classification loss: 0.54591 | Regression loss: 0.50939 | Running loss: 1.53584
# Epoch: 0 | Iteration: 60 | Classification loss: 0.44154 | Regression loss: 0.44896 | Running loss: 1.48505
# Epoch: 0 | Iteration: 80 | Classification loss: 0.80868 | Regression loss: 0.96335 | Running loss: 1.49945
# Epoch: 0 | Iteration: 100 | Classification loss: 0.52932 | Regression loss: 1.00239 | Running loss: 1.45219
# Epoch: 0 | Iteration: 120 | Classification loss: 0.32023 | Regression loss: 0.54018 | Running loss: 1.45151
# Epoch: 0 | Iteration: 160 | Classification loss: 0.30034 | Regression loss: 0.46214 | Running loss: 1.41224
# Epoch: 0 | Iteration: 180 | Classification loss: 0.65020 | Regression loss: 1.01035 | Running loss: 1.41864
# Epoch: 0 | Iteration: 200 | Classification loss: 0.66428 | Regression loss: 0.98781 | Running loss: 1.41980
# Epoch: 0 | Iteration: 220 | Classification loss: 0.31846 | Regression loss: 0.50496 | Running loss: 1.45653
# Epoch: 0 | Iteration: 240 | Classification loss: 0.70910 | Regression loss: 0.95706 | Running loss: 1.45290
# Epoch: 0 | Iteration: 260 | Classification loss: 0.58253 | Regression loss: 1.01401 | Running loss: 1.44212
# Epoch: 0 | Iteration: 280 | Classification loss: 0.34591 | Regression loss: 0.49780 | Running loss: 1.44283
# Epoch: 0 | Iteration: 340 | Classification loss: 0.20511 | Regression loss: 0.42951 | Running loss: 1.41451
# Epoch: 0 | Iteration: 380 | Classification loss: 0.32186 | Regression loss: 0.48830 | Running loss: 1.40490
# Epoch: 0 | Iteration: 400 | Classification loss: 0.34116 | Regression loss: 0.43613 | Running loss: 1.38700
# Epoch: 0 | Iteration: 420 | Classification loss: 0.82521 | Regression loss: 0.90642 | Running loss: 1.37716
# Epoch: 0 | Iteration: 440 | Classification loss: 0.50376 | Regression loss: 0.67414 | Running loss: 1.36069
# Epoch: 0 | Iteration: 460 | Classification loss: 0.63243 | Regression loss: 0.88691 | Running loss: 1.35785
# Epoch: 0 | Iteration: 480 | Classification loss: 0.38399 | Regression loss: 0.45026 | Running loss: 1.35368
# Epoch: 0 | Iteration: 500 | Classification loss: 0.32179 | Regression loss: 0.40554 | Running loss: 1.35266
# Epoch: 0 | Iteration: 520 | Classification loss: 0.22737 | Regression loss: 0.41439 | Running loss: 1.35378
# Epoch: 0 | Iteration: 560 | Classification loss: 0.61759 | Regression loss: 0.57915 | Running loss: 1.35272
# Epoch: 0 | Iteration: 580 | Classification loss: 0.58810 | Regression loss: 0.99352 | Running loss: 1.33850
# Epoch: 0 | Iteration: 600 | Classification loss: 0.78759 | Regression loss: 1.06392 | Running loss: 1.33159
# Epoch: 0 | Iteration: 620 | Classification loss: 0.25004 | Regression loss: 0.37126 | Running loss: 1.32365
# Epoch: 0 | Iteration: 640 | Classification loss: 0.31507 | Regression loss: 0.48554 | Running loss: 1.32157
# Epoch: 0 | Iteration: 660 | Classification loss: 0.64315 | Regression loss: 0.88649 | Running loss: 1.31166
# Epoch: 0 | Iteration: 680 | Classification loss: 0.67198 | Regression loss: 0.95398 | Running loss: 1.30245
# Epoch: 0 | Iteration: 720 | Classification loss: 0.89687 | Regression loss: 0.90947 | Running loss: 1.29297
# Epoch: 0 | Iteration: 740 | Classification loss: 0.27910 | Regression loss: 0.47651 | Running loss: 1.28425
# Epoch: 0 | Iteration: 760 | Classification loss: 0.57898 | Regression loss: 0.77060 | Running loss: 1.26192
# Epoch: 0 | Iteration: 780 | Classification loss: 0.99300 | Regression loss: 0.39925 | Running loss: 1.25982
# Epoch: 0 | Iteration: 800 | Classification loss: 0.52700 | Regression loss: 0.46881 | Running loss: 1.25128
# Epoch: 0 | Iteration: 840 | Classification loss: 0.19292 | Regression loss: 0.35436 | Running loss: 1.23555
# Epoch: 0 | Iteration: 860 | Classification loss: 0.44383 | Regression loss: 0.47069 | Running loss: 1.22875
# Epoch: 0 | Iteration: 880 | Classification loss: 0.21757 | Regression loss: 0.34123 | Running loss: 1.22921
# Epoch: 0 | Iteration: 900 | Classification loss: 0.39450 | Regression loss: 0.60781 | Running loss: 1.22804
# Epoch: 0 | Iteration: 920 | Classification loss: 0.76136 | Regression loss: 0.86793 | Running loss: 1.22280
# Epoch: 0 | Iteration: 940 | Classification loss: 0.18660 | Regression loss: 0.28085 | Running loss: 1.22328
# Epoch: 0 | Iteration: 1000 | Classification loss: 0.68534 | Regression loss: 0.98182 | Running loss: 1.22418
# Epoch: 0 | Iteration: 1040 | Classification loss: 0.30417 | Regression loss: 0.56714 | Running loss: 1.21898
# Epoch: 0 | Iteration: 1060 | Classification loss: 0.53298 | Regression loss: 0.93893 | Running loss: 1.20588
# Epoch: 0 | Iteration: 1080 | Classification loss: 0.66134 | Regression loss: 0.90725 | Running loss: 1.19655
# Epoch: 0 | Iteration: 1100 | Classification loss: 0.19625 | Regression loss: 0.35143 | Running loss: 1.19397
# Epoch: 0 | Iteration: 1120 | Classification loss: 0.43290 | Regression loss: 0.70126 | Running loss: 1.19110
# Epoch: 0 | Iteration: 1140 | Classification loss: 0.27143 | Regression loss: 0.38540 | Running loss: 1.18451
# Epoch: 0 | Iteration: 1160 | Classification loss: 0.48904 | Regression loss: 0.81542 | Running loss: 1.18454
# Epoch: 0 | Iteration: 1180 | Classification loss: 0.42326 | Regression loss: 0.56004 | Running loss: 1.18470
# Epoch: 0 | Iteration: 1200 | Classification loss: 0.55440 | Regression loss: 0.82523 | Running loss: 1.17609
# Epoch: 0 | Iteration: 1220 | Classification loss: 0.29219 | Regression loss: 0.31418 | Running loss: 1.17836
# Evaluating dataset on validation
# bovie Recall: 0.5969668178660456
# bovie Precision: 0.02238287765639327
# forceps Recall: 0.4664187806853587
# forceps Precision: 0.014497722654788487
# needledriver Recall: 0.5760548163311725
# needledriver Precision: 0.049999489774319866
#
# mAP:
# bovie: 0.12414324706299408
# forceps: 0.026448124982921373
# needledriver: 0.12053841474291156
# Overall: 0.09037659559627566
# {'bovie': [71, 716], 'scalpel': [0, 0], 'forceps': [83, 615], 'needledriver': [115, 1031], 'background': [84, 610]}
# 0:11:10
# to train 1 epochs
# Epoch: 1 | Iteration: 20 | Classification loss: 0.35666 | Regression loss: 0.70767 | Running loss: 1.17421
# Epoch: 1 | Iteration: 40 | Classification loss: 0.57420 | Regression loss: 0.90009 | Running loss: 1.17131
# Epoch: 1 | Iteration: 60 | Classification loss: 0.50299 | Regression loss: 0.74884 | Running loss: 1.16032
# Epoch: 1 | Iteration: 80 | Classification loss: 0.58115 | Regression loss: 1.06996 | Running loss: 1.15456
# Epoch: 1 | Iteration: 100 | Classification loss: 0.50750 | Regression loss: 0.80432 | Running loss: 1.14484
# Epoch: 1 | Iteration: 120 | Classification loss: 0.41832 | Regression loss: 0.85952 | Running loss: 1.14636
# Epoch: 1 | Iteration: 160 | Classification loss: 0.18717 | Regression loss: 0.46006 | Running loss: 1.13815
# Epoch: 1 | Iteration: 180 | Classification loss: 0.25782 | Regression loss: 0.42307 | Running loss: 1.13371
# Epoch: 1 | Iteration: 200 | Classification loss: 0.58059 | Regression loss: 0.53109 | Running loss: 1.13341
# Epoch: 1 | Iteration: 220 | Classification loss: 0.69421 | Regression loss: 0.83828 | Running loss: 1.12788
# Epoch: 1 | Iteration: 240 | Classification loss: 0.69353 | Regression loss: 0.85189 | Running loss: 1.11958
# Epoch: 1 | Iteration: 260 | Classification loss: 0.67080 | Regression loss: 0.97332 | Running loss: 1.12372
# Epoch: 1 | Iteration: 280 | Classification loss: 0.34043 | Regression loss: 0.69588 | Running loss: 1.12272
# Epoch: 1 | Iteration: 300 | Classification loss: 0.24482 | Regression loss: 0.37060 | Running loss: 1.11188
# Epoch: 1 | Iteration: 320 | Classification loss: 0.55953 | Regression loss: 0.80541 | Running loss: 1.11502
# Epoch: 1 | Iteration: 340 | Classification loss: 0.21645 | Regression loss: 0.49428 | Running loss: 1.12278
# Epoch: 1 | Iteration: 380 | Classification loss: 0.26521 | Regression loss: 0.48092 | Running loss: 1.10258
# Epoch: 1 | Iteration: 400 | Classification loss: 0.74853 | Regression loss: 0.80041 | Running loss: 1.10088
# Epoch: 1 | Iteration: 420 | Classification loss: 0.56034 | Regression loss: 0.76256 | Running loss: 1.09060
# Epoch: 1 | Iteration: 440 | Classification loss: 0.47034 | Regression loss: 0.78253 | Running loss: 1.08790
# Epoch: 1 | Iteration: 460 | Classification loss: 0.17480 | Regression loss: 0.36530 | Running loss: 1.08681
# Epoch: 1 | Iteration: 480 | Classification loss: 0.29493 | Regression loss: 0.46857 | Running loss: 1.07239
# Epoch: 1 | Iteration: 500 | Classification loss: 0.20020 | Regression loss: 0.26256 | Running loss: 1.07985
# Epoch: 1 | Iteration: 520 | Classification loss: 0.40495 | Regression loss: 0.70394 | Running loss: 1.07469
# Epoch: 1 | Iteration: 680 | Classification loss: 0.40953 | Regression loss: 0.64717 | Running loss: 1.07107
# Epoch: 1 | Iteration: 700 | Classification loss: 0.24999 | Regression loss: 0.38322 | Running loss: 1.06782
# Epoch: 1 | Iteration: 720 | Classification loss: 0.21390 | Regression loss: 0.37423 | Running loss: 1.06343
# Epoch: 1 | Iteration: 740 | Classification loss: 0.41532 | Regression loss: 0.65827 | Running loss: 1.05948
# Epoch: 1 | Iteration: 760 | Classification loss: 0.36402 | Regression loss: 0.70372 | Running loss: 1.05222
# Epoch: 1 | Iteration: 800 | Classification loss: 0.13389 | Regression loss: 0.36547 | Running loss: 1.05302
# Epoch: 1 | Iteration: 820 | Classification loss: 0.32805 | Regression loss: 0.64853 | Running loss: 1.05275
# Epoch: 1 | Iteration: 840 | Classification loss: 0.31216 | Regression loss: 0.59624 | Running loss: 1.05724
# Epoch: 1 | Iteration: 860 | Classification loss: 0.55809 | Regression loss: 0.72448 | Running loss: 1.04549
# Epoch: 1 | Iteration: 880 | Classification loss: 0.33487 | Regression loss: 0.85016 | Running loss: 1.03508
# Epoch: 1 | Iteration: 900 | Classification loss: 0.43154 | Regression loss: 0.86173 | Running loss: 1.03984
# Epoch: 1 | Iteration: 920 | Classification loss: 0.23994 | Regression loss: 0.40989 | Running loss: 1.03624
# Epoch: 1 | Iteration: 940 | Classification loss: 0.41295 | Regression loss: 0.57732 | Running loss: 1.03405
# Epoch: 1 | Iteration: 960 | Classification loss: 0.26891 | Regression loss: 0.45705 | Running loss: 1.03136
# Epoch: 1 | Iteration: 980 | Classification loss: 0.50521 | Regression loss: 0.78886 | Running loss: 1.03641
# Epoch: 1 | Iteration: 1000 | Classification loss: 0.60463 | Regression loss: 0.76604 | Running loss: 1.03357
# Epoch: 1 | Iteration: 1040 | Classification loss: 0.37093 | Regression loss: 0.40329 | Running loss: 1.02789
# Epoch: 1 | Iteration: 1060 | Classification loss: 0.27189 | Regression loss: 0.35217 | Running loss: 1.03094
# Epoch: 1 | Iteration: 1080 | Classification loss: 0.29630 | Regression loss: 0.28998 | Running loss: 1.02996
# Epoch: 1 | Iteration: 1100 | Classification loss: 0.29110 | Regression loss: 0.40735 | Running loss: 1.02759
# Epoch: 1 | Iteration: 1120 | Classification loss: 0.58019 | Regression loss: 0.96390 | Running loss: 1.02552
# Epoch: 1 | Iteration: 1140 | Classification loss: 0.31784 | Regression loss: 0.45328 | Running loss: 1.01986
# Epoch: 1 | Iteration: 1160 | Classification loss: 0.27106 | Regression loss: 0.41976 | Running loss: 1.01666
# Epoch: 1 | Iteration: 1180 | Classification loss: 0.37134 | Regression loss: 0.56932 | Running loss: 1.01853
# Epoch: 1 | Iteration: 1200 | Classification loss: 0.17410 | Regression loss: 0.36138 | Running loss: 1.02220
# Epoch: 1 | Iteration: 1220 | Classification loss: 0.60022 | Regression loss: 0.68202 | Running loss: 1.01394
# Evaluating dataset on training
# bovie Recall: 0.7827189221464786
# bovie Precision: 0.03732065443453263
# forceps Recall: 0.10195058527902505
# forceps Precision: 0.019677032975104133
# needledriver Recall: 0.8246220821093067
# needledriver Precision: 0.03280586153175153
#
# mAP:
# bovie: 0.27838496194740237
# forceps: 0.004039237007882014
# needledriver: 0.18824250749654609
# Overall: 0.15688890215061016
# Evaluating dataset on validation
# bovie Recall: 0.7874544945393447
# bovie Precision: 0.03227962857279711
# forceps Recall: 0.09504152538208266
# forceps Precision: 0.0389665701787354
# needledriver Recall: 0.8062763432117458
# needledriver Precision: 0.03784816953317398
#
# mAP:
# bovie: 0.16248864336203517
# forceps: 0.013497619019150864
# needledriver: 0.1722254509854786
# Overall: 0.11607057112222154
# {'bovie': [151, 1392], 'scalpel': [0, 0], 'forceps': [154, 1260], 'needledriver': [281, 2101], 'background': [143, 1236]}
# 0:33:33
# to train 2 epochs
# Epoch: 2 | Iteration: 0 | Classification loss: 0.20020 | Regression loss: 0.32669 | Running loss: 1.01352
# Epoch: 2 | Iteration: 20 | Classification loss: 0.19671 | Regression loss: 0.34472 | Running loss: 1.02560
# Epoch: 2 | Iteration: 40 | Classification loss: 0.69270 | Regression loss: 0.66751 | Running loss: 1.02662
# Epoch: 2 | Iteration: 60 | Classification loss: 0.39573 | Regression loss: 0.57295 | Running loss: 1.02801
# Epoch: 2 | Iteration: 80 | Classification loss: 0.41905 | Regression loss: 0.65773 | Running loss: 1.03288
# Epoch: 2 | Iteration: 100 | Classification loss: 0.50473 | Regression loss: 0.94330 | Running loss: 1.02050
# Epoch: 2 | Iteration: 120 | Classification loss: 0.18517 | Regression loss: 0.36624 | Running loss: 1.02339
# Epoch: 2 | Iteration: 160 | Classification loss: 0.21172 | Regression loss: 0.40736 | Running loss: 1.01907
# Epoch: 2 | Iteration: 180 | Classification loss: 0.22643 | Regression loss: 0.54223 | Running loss: 1.01507
# Epoch: 2 | Iteration: 220 | Classification loss: 0.51297 | Regression loss: 0.67138 | Running loss: 1.00495
# Epoch: 2 | Iteration: 240 | Classification loss: 0.30738 | Regression loss: 0.62682 | Running loss: 1.01669
# Epoch: 2 | Iteration: 260 | Classification loss: 0.45767 | Regression loss: 0.89842 | Running loss: 1.02481
# Epoch: 2 | Iteration: 280 | Classification loss: 0.45387 | Regression loss: 0.60071 | Running loss: 1.02090
# Epoch: 2 | Iteration: 300 | Classification loss: 0.65314 | Regression loss: 0.98247 | Running loss: 1.02511
# Epoch: 2 | Iteration: 320 | Classification loss: 0.44890 | Regression loss: 0.75463 | Running loss: 1.01984
# Epoch: 2 | Iteration: 340 | Classification loss: 0.37233 | Regression loss: 0.66252 | Running loss: 1.02641
# Epoch: 2 | Iteration: 360 | Classification loss: 0.57555 | Regression loss: 0.88168 | Running loss: 1.02465
# Epoch: 2 | Iteration: 400 | Classification loss: 0.70598 | Regression loss: 0.90692 | Running loss: 1.03078
# Epoch: 2 | Iteration: 420 | Classification loss: 0.24057 | Regression loss: 0.33556 | Running loss: 1.02019
# Epoch: 2 | Iteration: 440 | Classification loss: 0.16765 | Regression loss: 0.39787 | Running loss: 1.02086
# Epoch: 2 | Iteration: 460 | Classification loss: 0.18740 | Regression loss: 0.38775 | Running loss: 1.01806
# Epoch: 2 | Iteration: 480 | Classification loss: 0.26511 | Regression loss: 0.38622 | Running loss: 1.02049
# Epoch: 2 | Iteration: 500 | Classification loss: 0.14761 | Regression loss: 0.24093 | Running loss: 1.01479
# Epoch: 2 | Iteration: 520 | Classification loss: 0.41679 | Regression loss: 0.67816 | Running loss: 1.00882
# Epoch: 2 | Iteration: 540 | Classification loss: 0.46606 | Regression loss: 0.95383 | Running loss: 1.00835
# Epoch: 2 | Iteration: 560 | Classification loss: 0.13113 | Regression loss: 0.32867 | Running loss: 0.99205
# Epoch: 2 | Iteration: 580 | Classification loss: 0.19369 | Regression loss: 0.32521 | Running loss: 0.98318
# Epoch: 2 | Iteration: 620 | Classification loss: 0.27340 | Regression loss: 0.47672 | Running loss: 0.97484
# Epoch: 2 | Iteration: 680 | Classification loss: 1.03850 | Regression loss: 0.40037 | Running loss: 0.97799
# Epoch: 2 | Iteration: 700 | Classification loss: 0.36951 | Regression loss: 0.54242 | Running loss: 0.98165
# Epoch: 2 | Iteration: 720 | Classification loss: 0.61764 | Regression loss: 0.88711 | Running loss: 0.97852
# Epoch: 2 | Iteration: 740 | Classification loss: 0.22351 | Regression loss: 0.38402 | Running loss: 0.98653
# Epoch: 2 | Iteration: 760 | Classification loss: 0.53664 | Regression loss: 0.68622 | Running loss: 0.98693
# Epoch: 2 | Iteration: 780 | Classification loss: 0.30757 | Regression loss: 0.68380 | Running loss: 0.98980
# Epoch: 2 | Iteration: 800 | Classification loss: 0.56017 | Regression loss: 0.80117 | Running loss: 0.98319
# Epoch: 2 | Iteration: 820 | Classification loss: 0.17177 | Regression loss: 0.29787 | Running loss: 0.97649
# Epoch: 2 | Iteration: 840 | Classification loss: 0.70063 | Regression loss: 0.75802 | Running loss: 0.97117
# Epoch: 2 | Iteration: 860 | Classification loss: 0.41908 | Regression loss: 0.62404 | Running loss: 0.96812
# Epoch: 2 | Iteration: 880 | Classification loss: 0.29548 | Regression loss: 0.51901 | Running loss: 0.96593
# Epoch: 2 | Iteration: 900 | Classification loss: 0.58692 | Regression loss: 0.74559 | Running loss: 0.96362
# Epoch: 2 | Iteration: 920 | Classification loss: 0.20317 | Regression loss: 0.38350 | Running loss: 0.95637
# Epoch: 2 | Iteration: 940 | Classification loss: 0.52758 | Regression loss: 0.66632 | Running loss: 0.95781
# Epoch: 2 | Iteration: 960 | Classification loss: 0.64037 | Regression loss: 0.82162 | Running loss: 0.96654
# Epoch: 2 | Iteration: 1000 | Classification loss: 0.23337 | Regression loss: 0.26105 | Running loss: 0.95439
# Epoch: 2 | Iteration: 1020 | Classification loss: 0.82585 | Regression loss: 0.29100 | Running loss: 0.95898
# Epoch: 2 | Iteration: 1040 | Classification loss: 0.88194 | Regression loss: 0.00000 | Running loss: 0.96100
# Epoch: 2 | Iteration: 1060 | Classification loss: 0.41652 | Regression loss: 0.84473 | Running loss: 0.96368
# Epoch: 2 | Iteration: 1080 | Classification loss: 0.36589 | Regression loss: 0.64742 | Running loss: 0.96154
# Epoch: 2 | Iteration: 1100 | Classification loss: 0.33061 | Regression loss: 0.37766 | Running loss: 0.96742
# Epoch: 2 | Iteration: 1120 | Classification loss: 0.45022 | Regression loss: 0.65782 | Running loss: 0.97382
# Epoch: 2 | Iteration: 1140 | Classification loss: 0.23832 | Regression loss: 0.33963 | Running loss: 0.97575
# Epoch: 2 | Iteration: 1180 | Classification loss: 0.67075 | Regression loss: 0.86072 | Running loss: 0.97453
# Epoch: 2 | Iteration: 1200 | Classification loss: 0.35385 | Regression loss: 0.69902 | Running loss: 0.96886
# Epoch: 2 | Iteration: 1220 | Classification loss: 0.51265 | Regression loss: 0.31994 | Running loss: 0.96426
# Evaluating dataset on validation
# bovie Recall: 0.7019572953736655
# bovie Precision: 0.08521909832266145
# forceps Recall: 0.4974467685174549
# forceps Precision: 0.03661583031231401
# needledriver Recall: 0.6134355767321819
# needledriver Precision: 0.047771193277801716
#
# mAP:
# bovie: 0.28897951191167676
# forceps: 0.07477141030728612
# needledriver: 0.13239859587454994
# Overall: 0.16538317269783762
# {'bovie': [224, 2076], 'scalpel': [0, 0], 'forceps': [218, 1928], 'needledriver': [387, 3138], 'background': [226, 1832]}
# 0:43:21
# to train 3 epochs
# Epoch: 3 | Iteration: 0 | Classification loss: 0.19278 | Regression loss: 0.30694 | Running loss: 0.96258
# Epoch: 3 | Iteration: 20 | Classification loss: 0.46588 | Regression loss: 0.64055 | Running loss: 0.95748
# Epoch: 3 | Iteration: 40 | Classification loss: 0.53259 | Regression loss: 0.82609 | Running loss: 0.95442
# Epoch: 3 | Iteration: 60 | Classification loss: 0.21523 | Regression loss: 0.38477 | Running loss: 0.94815
# Epoch: 3 | Iteration: 80 | Classification loss: 0.65548 | Regression loss: 0.77611 | Running loss: 0.95649
# Epoch: 3 | Iteration: 100 | Classification loss: 0.41714 | Regression loss: 0.69208 | Running loss: 0.95061
# Epoch: 3 | Iteration: 120 | Classification loss: 0.13684 | Regression loss: 0.30313 | Running loss: 0.95124
# Epoch: 3 | Iteration: 140 | Classification loss: 0.38971 | Regression loss: 0.63496 | Running loss: 0.94821
# Epoch: 3 | Iteration: 160 | Classification loss: 0.49435 | Regression loss: 0.68371 | Running loss: 0.94895
# Epoch: 3 | Iteration: 180 | Classification loss: 0.58674 | Regression loss: 0.82477 | Running loss: 0.95170
# Epoch: 3 | Iteration: 200 | Classification loss: 0.21069 | Regression loss: 0.45068 | Running loss: 0.95035
# Epoch: 3 | Iteration: 220 | Classification loss: 0.21147 | Regression loss: 0.38435 | Running loss: 0.95401
# Epoch: 3 | Iteration: 240 | Classification loss: 0.28676 | Regression loss: 0.37516 | Running loss: 0.95591
# Epoch: 3 | Iteration: 260 | Classification loss: 0.38305 | Regression loss: 0.69019 | Running loss: 0.95670
# Epoch: 3 | Iteration: 280 | Classification loss: 0.31051 | Regression loss: 0.69161 | Running loss: 0.94882
# Epoch: 3 | Iteration: 320 | Classification loss: 0.26249 | Regression loss: 0.71785 | Running loss: 0.94606
# Epoch: 3 | Iteration: 340 | Classification loss: 0.57216 | Regression loss: 0.82899 | Running loss: 0.93968
# Epoch: 3 | Iteration: 400 | Classification loss: 0.14152 | Regression loss: 0.33393 | Running loss: 0.93634
# Epoch: 3 | Iteration: 420 | Classification loss: 0.27273 | Regression loss: 0.45777 | Running loss: 0.93540
# Epoch: 3 | Iteration: 440 | Classification loss: 0.51217 | Regression loss: 0.79113 | Running loss: 0.94015
# Epoch: 3 | Iteration: 460 | Classification loss: 0.37174 | Regression loss: 0.81898 | Running loss: 0.94143
# Epoch: 3 | Iteration: 480 | Classification loss: 0.19725 | Regression loss: 0.22675 | Running loss: 0.94494
# Epoch: 3 | Iteration: 500 | Classification loss: 0.45749 | Regression loss: 0.85235 | Running loss: 0.94173
# Epoch: 3 | Iteration: 520 | Classification loss: 0.38121 | Regression loss: 0.49318 | Running loss: 0.94167
# Epoch: 3 | Iteration: 540 | Classification loss: 0.12422 | Regression loss: 0.21354 | Running loss: 0.94306
# Epoch: 3 | Iteration: 560 | Classification loss: 0.54160 | Regression loss: 1.11894 | Running loss: 0.94389
# Epoch: 3 | Iteration: 580 | Classification loss: 0.36587 | Regression loss: 0.54522 | Running loss: 0.94815
# Epoch: 3 | Iteration: 600 | Classification loss: 0.18467 | Regression loss: 0.25851 | Running loss: 0.94976
# Epoch: 3 | Iteration: 620 | Classification loss: 0.40314 | Regression loss: 0.70282 | Running loss: 0.94192
# Epoch: 3 | Iteration: 640 | Classification loss: 1.02937 | Regression loss: 0.00000 | Running loss: 0.93728
# Epoch: 3 | Iteration: 660 | Classification loss: 0.75689 | Regression loss: 0.00000 | Running loss: 0.93224
# Epoch: 3 | Iteration: 680 | Classification loss: 0.40326 | Regression loss: 0.76580 | Running loss: 0.93940
# Epoch: 3 | Iteration: 700 | Classification loss: 0.45385 | Regression loss: 0.68306 | Running loss: 0.93764
# Epoch: 3 | Iteration: 720 | Classification loss: 0.58793 | Regression loss: 0.93427 | Running loss: 0.93985
# Epoch: 3 | Iteration: 740 | Classification loss: 0.18972 | Regression loss: 0.38047 | Running loss: 0.93484
# Epoch: 3 | Iteration: 760 | Classification loss: 0.71852 | Regression loss: 0.90832 | Running loss: 0.93016
# Epoch: 3 | Iteration: 780 | Classification loss: 0.39204 | Regression loss: 0.83077 | Running loss: 0.92600
# Epoch: 3 | Iteration: 800 | Classification loss: 0.25253 | Regression loss: 0.39953 | Running loss: 0.91980
# Epoch: 3 | Iteration: 820 | Classification loss: 0.20711 | Regression loss: 0.30827 | Running loss: 0.92263
# Epoch: 3 | Iteration: 840 | Classification loss: 0.13429 | Regression loss: 0.25350 | Running loss: 0.92241
# Epoch: 3 | Iteration: 860 | Classification loss: 0.24083 | Regression loss: 0.25339 | Running loss: 0.92108
# Epoch: 3 | Iteration: 880 | Classification loss: 0.26888 | Regression loss: 0.45074 | Running loss: 0.92396
# Epoch: 3 | Iteration: 900 | Classification loss: 0.19107 | Regression loss: 0.33231 | Running loss: 0.91871
# Epoch: 3 | Iteration: 920 | Classification loss: 0.23489 | Regression loss: 0.38015 | Running loss: 0.91911
# Epoch: 3 | Iteration: 940 | Classification loss: 0.62464 | Regression loss: 0.99815 | Running loss: 0.92440
# Epoch: 3 | Iteration: 980 | Classification loss: 0.13573 | Regression loss: 0.25099 | Running loss: 0.91106
# Epoch: 3 | Iteration: 1000 | Classification loss: 0.81323 | Regression loss: 0.82108 | Running loss: 0.90436
# Epoch: 3 | Iteration: 1020 | Classification loss: 0.50949 | Regression loss: 0.75657 | Running loss: 0.90132
# Epoch: 3 | Iteration: 1060 | Classification loss: 0.33114 | Regression loss: 0.46428 | Running loss: 0.90167
# Epoch: 3 | Iteration: 1080 | Classification loss: 0.12906 | Regression loss: 0.36665 | Running loss: 0.90537
# Epoch: 3 | Iteration: 1100 | Classification loss: 0.40528 | Regression loss: 0.36114 | Running loss: 0.90639
# Epoch: 3 | Iteration: 1120 | Classification loss: 0.08292 | Regression loss: 0.21353 | Running loss: 0.90013
# Epoch: 3 | Iteration: 1140 | Classification loss: 0.62706 | Regression loss: 0.62095 | Running loss: 0.89613
# Epoch: 3 | Iteration: 1160 | Classification loss: 0.40799 | Regression loss: 0.67875 | Running loss: 0.90271
# Epoch: 3 | Iteration: 1220 | Classification loss: 0.42557 | Regression loss: 0.65972 | Running loss: 0.90260
# Evaluating dataset on validation
# 296/430

# %%
# Function to generate stacked histograms from saved batchlogger.txt file from the end of training! 

# Pre-calls if from scratch: 
# import numpy as np
# LOGS_DIR = '/home/ubuntu/surgery-tool-detection/logs/'

def generateHistograms(model_name): 
    LOG_DIR = LOGS_DIR + model_name + '/'
    filename = '{}_finalBatchLogger.txt'.format(LOG_DIR + model_name) 

    import ast 
    import matplotlib.pyplot as plt 

    with open(filename, 'r') as f:
        tool_dict = ast.literal_eval(f.readlines()[-3]) 

    with open(filename, 'r') as f:
        tool_frame_dict = ast.literal_eval(f.readlines()[-2]) 

    print("Tool frames log") 
    print(tool_frame_dict)
    print("Tool instances log") 
    print(tool_dict) 

    def stackedHistogram(dict_, title=None): 
        c = []
        v = []             
        for key, val in dict_.items(): 
            c.append(key) 
            v.append(val)
        v = np.array(v) 

        plt.bar(range(len(c)), v[:,0], label='Original')
        plt.bar(range(len(c)), v[:,1], bottom=v[:,0], label='Augmented') 
        if title is not None: plt.title(title) 
        plt.xticks(range(len(c)), c)
        plt.legend(loc="upper right")
        plt.show()

    stackedHistogram(tool_frame_dict, title="{}: Tool frame logger".format(model_name))  
    stackedHistogram(tool_dict, title="{}: Tool instances logger".format(model_name))

# %%
model_name = '8.23_Model2'
generateHistograms(model_name)
# Out:
# Tool frames log
# {'bovie': [16205, 0], 'scalpel': [3570, 0], 'forceps': [13965, 0], 'needledriver': [22785, 0], 'background': [42140, 0]}
# Tool instances log
# {'bovie': [16415, 0], 'scalpel': [3570, 0], 'forceps': [16170, 0], 'needledriver': [34195, 0], 'background': [42140, 0]}

# %%
model_name = '8.23_Model3'
generateHistograms(model_name)
# Out:
# Tool frames log
# {'bovie': [6167, 14615], 'scalpel': [4122, 9530], 'forceps': [5595, 13085], 'needledriver': [8851, 20212], 'background': [7120, 16447]}
# Tool instances log
# {'bovie': [6218, 14805], 'scalpel': [4122, 9530], 'forceps': [6435, 15146], 'needledriver': [13524, 30693], 'background': [7120, 16447]}

# %%
model_name = '8.25_Model1'
generateHistograms(model_name)
# Out:
# Tool frames log
# {'bovie': [2232, 19645], 'scalpel': [1623, 14221], 'forceps': [2066, 17939], 'needledriver': [3032, 27038], 'background': [1944, 17713]}
# Tool instances log
# {'bovie': [2249, 19921], 'scalpel': [1623, 14221], 'forceps': [2370, 20535], 'needledriver': [4574, 41096], 'background': [1944, 17713]}
